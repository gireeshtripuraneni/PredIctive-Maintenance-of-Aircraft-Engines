# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

base_path = "/content/drive/MyDrive/Dataset/"

# Expected filenames
train_path = base_path + "PM_train.xlsx"
test_path  = base_path + "PM_test.xlsx"
truth_path = base_path + "PM_truth.xlsx"

# Check if files exist
for p in [train_path, test_path, truth_path]:
    print(p, "->", "FOUND" if os.path.exists(p) else "NOT FOUND")
# Out:
# /content/drive/MyDrive/Dataset/PM_train.xlsx -> FOUND
# /content/drive/MyDrive/Dataset/PM_test.xlsx -> FOUND
# /content/drive/MyDrive/Dataset/PM_truth.xlsx -> FOUND

# %%
import pandas as pd

df_train = pd.read_excel(train_path)
df_test  = pd.read_excel(test_path)
df_truth = pd.read_excel(truth_path)

print("Train:", df_train.shape)
print("Test :", df_test.shape)
print("Truth:", df_truth.shape)

display(df_train.head())
display(df_test.head())
display(df_truth.head())
